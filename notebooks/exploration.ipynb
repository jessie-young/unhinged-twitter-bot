# %%
import daft

# %%
df = daft.read_json("data/agent-logs/**")

# %%
df = df.with_column("prompt", df["data"].struct.get("prompt"))
df.show()
# Out:
# ╭────────────────────────────┬─────────┬────────┬──────────────────┬───────────────────────┬───────────────────────────╮
# │ session_id                 ┆ log_idx ┆ type   ┆ prompt_type      ┆ data                  ┆ prompt                    │
# │ ---                        ┆ ---     ┆ ---    ┆ ---              ┆ ---                   ┆ ---                       │
# │ Utf8                       ┆ Int64   ┆ Utf8   ┆ Utf8             ┆ Struct[prompt: Utf8,  ┆ Utf8                      │
# │                            ┆         ┆        ┆                  ┆ response: Utf8]       ┆                           │
# ╞════════════════════════════╪═════════╪════════╪══════════════════╪═══════════════════════╪═══════════════════════════╡
# │ Toasted Entrepreneurial    ┆ 0       ┆ prompt ┆ tweet_relevance  ┆ {prompt: Given this   ┆ Given this tweet: "       │
# │ Spiri…                     ┆         ┆        ┆                  ┆ tweet: "              ┆ Chain of …                │
# │                            ┆         ┆        ┆                  ┆ …                     ┆                           │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Quirky                     ┆ 0       ┆ prompt ┆ tweet_relevance  ┆ {prompt: Given this   ┆ Given this tweet:         │
# │ Quantum_7b71e9c4-8f94-…    ┆         ┆        ┆                  ┆ tweet: "S…            ┆ "Startups a…              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted Entrepreneurial    ┆ 0       ┆ prompt ┆ tweet_relevance  ┆ {prompt: Given this   ┆ Given this tweet: "       │
# │ Spiri…                     ┆         ┆        ┆                  ┆ tweet: "              ┆ Chain of …                │
# │                            ┆         ┆        ┆                  ┆ …                     ┆                           │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted Entrepreneurial    ┆ 1       ┆ prompt ┆ chain_of_thought ┆ {prompt: Given this   ┆ Given this tweet: "       │
# │ Spiri…                     ┆         ┆        ┆                  ┆ tweet: "              ┆ Chain of …                │
# │                            ┆         ┆        ┆                  ┆ …                     ┆                           │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted Entrepreneurial    ┆ 2       ┆ prompt ┆ tweet_generation ┆ {prompt: Based on the ┆ Based on the analysis,    │
# │ Spiri…                     ┆         ┆        ┆                  ┆ analysi…              ┆ genera…                   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted Entrepreneurial    ┆ 0       ┆ prompt ┆ tweet_relevance  ┆ {prompt: Given this   ┆ Given this tweet: "Paul   │
# │ Spiri…                     ┆         ┆        ┆                  ┆ tweet: "P…            ┆ Graha…                    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted Entrepreneurial    ┆ 1       ┆ prompt ┆ chain_of_thought ┆ {prompt: Given this   ┆ Given this tweet: "Paul   │
# │ Spiri…                     ┆         ┆        ┆                  ┆ tweet: "P…            ┆ Graha…                    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted Entrepreneurial    ┆ 2       ┆ prompt ┆ tweet_generation ┆ {prompt: Based on the ┆ Based on the analysis,    │
# │ Spiri…                     ┆         ┆        ┆                  ┆ analysi…              ┆ genera…                   │
# ╰────────────────────────────┴─────────┴────────┴──────────────────┴───────────────────────┴───────────────────────────╯
#
# (Showing first 8 rows)

# %%
df = df.with_column("response", df["data"].struct.get("response"))
df.show()
# Out:
# ╭─────────────────────┬─────────┬────────┬────────────┬─────────────────────┬─────────────────────┬────────────────────╮
# │ session_id          ┆ log_idx ┆ type   ┆      …     ┆ data                ┆ prompt              ┆ response           │
# │ ---                 ┆ ---     ┆ ---    ┆            ┆ ---                 ┆ ---                 ┆ ---                │
# │ Utf8                ┆ Int64   ┆ Utf8   ┆ (1 hidden) ┆ Struct[prompt:      ┆ Utf8                ┆ Utf8               │
# │                     ┆         ┆        ┆            ┆ Utf8, response:     ┆                     ┆                    │
# │                     ┆         ┆        ┆            ┆ Utf8]               ┆                     ┆                    │
# ╞═════════════════════╪═════════╪════════╪════════════╪═════════════════════╪═════════════════════╪════════════════════╡
# │ Toasted             ┆ 0       ┆ prompt ┆ …          ┆ {prompt: Given this ┆ Given this tweet: " ┆ NO: The main topic │
# │ Entrepreneurial     ┆         ┆        ┆            ┆ tweet: "            ┆ Chain of …          ┆ of the twe…        │
# │ Spiri…              ┆         ┆        ┆            ┆ …                   ┆                     ┆                    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Quirky Quantum_7b71 ┆ 0       ┆ prompt ┆ …          ┆ {prompt: Given this ┆ Given this tweet:   ┆ 1. The main topic  │
# │ e9c4-8f94-…         ┆         ┆        ┆            ┆ tweet: "S…          ┆ "Startups a…        ┆ of the twee…       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted             ┆ 0       ┆ prompt ┆ …          ┆ {prompt: Given this ┆ Given this tweet: " ┆ YES: The tweet     │
# │ Entrepreneurial     ┆         ┆        ┆            ┆ tweet: "            ┆ Chain of …          ┆ explores the e…    │
# │ Spiri…              ┆         ┆        ┆            ┆ …                   ┆                     ┆                    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted             ┆ 1       ┆ prompt ┆ …          ┆ {prompt: Given this ┆ Given this tweet: " ┆ Analyzing the      │
# │ Entrepreneurial     ┆         ┆        ┆            ┆ tweet: "            ┆ Chain of …          ┆ tweet, the user…   │
# │ Spiri…              ┆         ┆        ┆            ┆ …                   ┆                     ┆                    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted             ┆ 2       ┆ prompt ┆ …          ┆ {prompt: Based on   ┆ Based on the        ┆ "Ah, the           │
# │ Entrepreneurial     ┆         ┆        ┆            ┆ the analysi…        ┆ analysis, genera…   ┆ mysterious tech    │
# │ Spiri…              ┆         ┆        ┆            ┆                     ┆                     ┆ danc…              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted             ┆ 0       ┆ prompt ┆ …          ┆ {prompt: Given this ┆ Given this tweet:   ┆ YES: The tweet is  │
# │ Entrepreneurial     ┆         ┆        ┆            ┆ tweet: "P…          ┆ "Paul Graha…        ┆ about Paul …       │
# │ Spiri…              ┆         ┆        ┆            ┆                     ┆                     ┆                    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted             ┆ 1       ┆ prompt ┆ …          ┆ {prompt: Given this ┆ Given this tweet:   ┆ Step 1: Analyzing  │
# │ Entrepreneurial     ┆         ┆        ┆            ┆ tweet: "P…          ┆ "Paul Graha…        ┆ the tweet          │
# │ Spiri…              ┆         ┆        ┆            ┆                     ┆                     ┆ T…                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted             ┆ 2       ┆ prompt ┆ …          ┆ {prompt: Based on   ┆ Based on the        ┆ Tweet: "Paul       │
# │ Entrepreneurial     ┆         ┆        ┆            ┆ the analysi…        ┆ analysis, genera…   ┆ Graham is the GO…  │
# │ Spiri…              ┆         ┆        ┆            ┆                     ┆                     ┆                    │
# ╰─────────────────────┴─────────┴────────┴────────────┴─────────────────────┴─────────────────────┴────────────────────╯
#
# (Showing first 8 rows)

# %%
df = df.exclude("data")
df.show()
# Out:
# ╭──────────────────────────┬─────────┬────────┬──────────────────┬──────────────────────────┬──────────────────────────╮
# │ session_id               ┆ log_idx ┆ type   ┆ prompt_type      ┆ prompt                   ┆ response                 │
# │ ---                      ┆ ---     ┆ ---    ┆ ---              ┆ ---                      ┆ ---                      │
# │ Utf8                     ┆ Int64   ┆ Utf8   ┆ Utf8             ┆ Utf8                     ┆ Utf8                     │
# ╞══════════════════════════╪═════════╪════════╪══════════════════╪══════════════════════════╪══════════════════════════╡
# │ Toasted Entrepreneurial  ┆ 0       ┆ prompt ┆ tweet_relevance  ┆ Given this tweet: "      ┆ NO: The main topic of    │
# │ Spiri…                   ┆         ┆        ┆                  ┆ Chain of …               ┆ the twe…                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Quirky                   ┆ 0       ┆ prompt ┆ tweet_relevance  ┆ Given this tweet:        ┆ 1. The main topic of the │
# │ Quantum_7b71e9c4-8f94-…  ┆         ┆        ┆                  ┆ "Startups a…             ┆ twee…                    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted Entrepreneurial  ┆ 0       ┆ prompt ┆ tweet_relevance  ┆ Given this tweet: "      ┆ YES: The tweet explores  │
# │ Spiri…                   ┆         ┆        ┆                  ┆ Chain of …               ┆ the e…                   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted Entrepreneurial  ┆ 1       ┆ prompt ┆ chain_of_thought ┆ Given this tweet: "      ┆ Analyzing the tweet, the │
# │ Spiri…                   ┆         ┆        ┆                  ┆ Chain of …               ┆ user…                    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted Entrepreneurial  ┆ 2       ┆ prompt ┆ tweet_generation ┆ Based on the analysis,   ┆ "Ah, the mysterious tech │
# │ Spiri…                   ┆         ┆        ┆                  ┆ genera…                  ┆ danc…                    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted Entrepreneurial  ┆ 0       ┆ prompt ┆ tweet_relevance  ┆ Given this tweet: "Paul  ┆ YES: The tweet is about  │
# │ Spiri…                   ┆         ┆        ┆                  ┆ Graha…                   ┆ Paul …                   │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted Entrepreneurial  ┆ 1       ┆ prompt ┆ chain_of_thought ┆ Given this tweet: "Paul  ┆ Step 1: Analyzing the    │
# │ Spiri…                   ┆         ┆        ┆                  ┆ Graha…                   ┆ tweet                    │
# │                          ┆         ┆        ┆                  ┆                          ┆ T…                       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Toasted Entrepreneurial  ┆ 2       ┆ prompt ┆ tweet_generation ┆ Based on the analysis,   ┆ Tweet: "Paul Graham is   │
# │ Spiri…                   ┆         ┆        ┆                  ┆ genera…                  ┆ the GO…                  │
# ╰──────────────────────────┴─────────┴────────┴──────────────────┴──────────────────────────┴──────────────────────────╯
#
# (Showing first 8 rows)

# %%
df.where(df["prompt_type"] == "tweet_generation").select("response").show()
# Out:
# ╭────────────────────────────────╮
# │ response                       │
# │ ---                            │
# │ Utf8                           │
# ╞════════════════════════════════╡
# │ "Ah, the mysterious tech danc… │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Tweet: "Paul Graham is the GO… │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ "Ah, the mysterious dance of … │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ "Ah, the mysterious tech danc… │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Tweet: "According to my resea… │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Tweet: The evolution of YC ov… │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ "Ah, the mysterious dance of … │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ Tweet: Ahoy, mateys! The Lyft… │
# ╰────────────────────────────────╯
#
# (Showing first 8 rows)
