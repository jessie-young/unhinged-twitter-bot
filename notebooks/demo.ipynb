# %% [markdown]
# # ~Unhinged~ Cringe Agents
#
# We built a little simulation Twitter world within which AI agents can tweet at each other... With the goal of making the most unhinged AI agents.
#
# However, we only succeeded at making cringe agents :(
#
# Here's our story...

# %% [markdown]
# ## Running a simulation

# %%
import os

os.chdir("../")

# %%
# Running a simulation
# !uv run simulate \
    demo_simulation \
    --tweets-file data/simulation_tweets/startup_tweets_v2.txt \
    --seed-memory-id startups
# Out:
# 2025-03-13 15:55:41,361 - unhinged_twitter_bot.simulation - WARNING - Seed table data/seed/startups.lance not found
# Spinning up simulation world...
# [+] Running 1/2
#  ✔ Network unhinged-twitter-bot_default      Created                       0.1s
#  ⠋ Volume "unhinged-twitter-bot_redis_data"  Creating                      0.0s
# WARN[0000] Found orphan containers ([unhinged-twitter-bot-batch-ingest-subscriber-1]) for this project. If you removed or renamed this service in your compose file, you can run this command with the --remove-orphans flag to clean it up.
# Waiting for services to start...
# [+] Running 4/5
#  ✔ Network unhinged-twitter-bot_default                      Created       0.1s
#  ✔ Volume "unhinged-twitter-bot_redis_data"                  Created       0.0s
#  ⠋ Container unhinged-twitter-bot-events-pubsub-1            Starting      0.1s
#  ✔ Container unhinged-twitter-bot-tweet-embedding-service-1  Created       0.0s
# ...

# %% [markdown]
# ## Ok, but wtf was it doing?
#
# **!! TODO: DESMOND DEMO REPLAY APP**

# %% [markdown]
# ## Let's analyze the results using Daft
#
# Which agent is the cringiest?
#
# Lastly, can we make a non-cringey agent?
#
# **!! TODO: JAY TO ADD CRINGE ANALYSIS**

# %% [markdown]
# ## Our journey to a non-cringe agent
#
# We also tried letting agents check with OpenAI if they were being cringey... (tool to check cringe)
#
# **!! TODO: DESMOND**

# %% [markdown]
# ## Let's try building our own non-cringey agent??
#
# **!! TODO: JAY**

# %% [markdown]
# ## Other Ideas?
#
# **!! TODO: JESSIE**
#
# ![image.png](attachment:1d1b03cf-8722-40f7-946a-c98d4751e817.png)
#
# ### Tools
#
# * Tweet search
#
# ### Knowledge
#
# * Vector search
